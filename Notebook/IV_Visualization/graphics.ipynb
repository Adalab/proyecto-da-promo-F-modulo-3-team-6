# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
# lo primero que hacemos es cargar el dataframe que vamos a usar para esta lección
df = pd.read_csv("raw_data_final_20231212.csv", index_col = 0 ) 
df.head()
# Out:
#    Age Attrition Businesstravel              Department  Education  \
# 0   51        No        Unknown  Research & Development          3
# 1   52        No        Unknown                 Unknown          4
# 2   42        No  travel_rarely  Research & Development          2
# 3   47        No  travel_rarely  Research & Development          4
# 4   46        No        Unknown                   Sales          3
#
#      Educationfield  Employeenumber Environmentsatisfaction  Gender  \
# 0           Unknown             162           Not Satisfied    Male
# 1     Life Sciences             259               Satisfied    Male
# 2  Technical Degree             319               Satisfied    Male
# 3           Medical            2069           Not Satisfied  Female
# 4  Technical Degree            2070           Not Satisfied  Female
#
#   Jobinvolvement   Joblevel            Jobrole Jobsatisfaction Maritalstatus  \
# 0           High  Executive  Research Director       Satisfied       Unknown
# 1       Moderate  Executive            Manager       Satisfied       Unknown
# 2           High  Executive            Manager  Very Satisfied       Married
# 3           High     Senior  Research Director       Satisfied       Married
# 4      Very High     Senior    Sales Executive   Not Satisfied      Divorced
#
#    Monthlyrate  Numcompaniesworked Overtime  Percentsalaryhike  \
# 0         6462                   7       No                 13
# 1         5678                   0  Unknown                 14
# 2         4933                   1       No                 11
# 3        26703                   3  Unknown                 19
# 4         7739                   2       No                 12
#
#   Relationshipsatisfaction  Stockoptionlevel  Trainingtimeslastyear  \
# 0                Satisfied                 0                      5
# 1            Not Satisfied                 1                      5
# 2           Very Satisfied                 0                      3
# 3       Somewhat Satisfied                 2                      2
# 4           Very Satisfied                 1                      5
#
#    Yearsatcompany  Yearssincelastpromotion  Yearswithcurrmanager  Datebirth  \
# 0              20                       15                    15       1972
# 1              33                       11                     9       1971
# 2              22                       11                    15       1981
# 3              20                        5                     6       1976
# 4              19                        2                     8       1977
#
#   Remotework  Dailyrate  Distancefromhome  Monthlyincome  Performancerating  \
# 0        Yes      684.0               6.0        19537.0                3.0
# 1        Yes      699.0               1.0        19999.0                3.0
# 2        Yes      532.0               4.0        19232.0                3.0
# 3         No      359.0               2.0        17169.0                3.0
# 4         No     1319.0               3.0         4884.6                3.0
#
#    Totalworkingyears  Worklifebalance  Hourlyrate
# 0               13.6              3.0        51.0
# 1               34.0              3.0        65.0
# 2               22.0              3.0        58.0
# 3               11.2              1.8        82.0
# 4               13.4              3.0        45.0

# %% [markdown]
# # GRÁFICOS PRESENTACIÓN BBDD

# %% [markdown]
# ### Distribución de edades por género

# %%
sns.histplot(x = "Age", 
             data = df, 
             hue = 'Gender',
             color = "violet", 
             kde = True, 
             bins = 10 );

# %% [markdown]
# ### Job level distribution

# %%
df_joblevel = df.groupby("Joblevel")["Employeenumber"].count().reset_index()
df_joblevel
# Out:
#       Joblevel  Employeenumber
# 0  Entry-level             555
# 1    Executive              70
# 2       Junior             546
# 3    Mid-level             228
# 4       Senior             111

# %%
colores = ["c", "cadetblue", "mediumseagreen", "seagreen", "teal", "turquoise", "lightseagreen"]


# creamos el gráfico basándonos en el DataFrame que hemos creado en el paso anterior
plt.pie("Employeenumber", labels= "Joblevel",
        data = df_joblevel, 
        autopct=  '%1.1f%%', 
        colors = colores, 
        textprops={'fontsize': 8}, 
        startangle=90);

# %%
sns.countplot(x = "Joblevel", 
              data = df, 
              color = "c");

plt.xticks(rotation = 45)
plt.xlabel("Job Level")
plt.ylabel("Count")
plt.title("Job Level Distribution");

# %% [markdown]
# ### Education level distribution

# %%
def education_level(dataframe):
    dict_map = {1: "Elementary School", 2: "Middle School", 3: "High School", 4: "College/University", 5: "Graduate School"}
    dataframe["Education"] = dataframe["Education"].map(dict_map)
    return dataframe
df= education_level(df)

# %%
df["Education"].value_counts()
# Out:
# High School           585
# College/University    411
# Middle School         293
# Elementary School     172
# Graduate School        49
# Name: Education, dtype: int64

# %%
df_educacion = df.groupby("Education")["Employeenumber"].count().reset_index()
df_educacion
# Out:
#             Education  Employeenumber
# 0  College/University             411
# 1   Elementary School             172
# 2     Graduate School              49
# 3         High School             585
# 4       Middle School             293

# %%
sns.set(style="whitegrid")
colores = ["c", "cadetblue", "mediumseagreen", "seagreen", "teal", "turquoise", "lightseagreen"]


# creamos el gráfico basándonos en el DataFrame que hemos creado en el paso anterior
plt.pie("Employeenumber", labels= "Education",
        data = df_educacion, 
        autopct=  '%1.1f%%', 
        colors = colores, 
        textprops={'fontsize': 8}, 
        startangle=90);

# %%
sns.countplot(x = "Education", 
              data = df, 
              color = "c");


plt.xlabel("Education level")
plt.ylabel("Count")
plt.title("Education Level Distribution");

# %% [markdown]
# # GRÁFICOS EN BASE a vars que no hacemos en el AB testing

# %%
df.head()
# Out:
#    Age Attrition Businesstravel              Department           Education  \
# 0   51        No        Unknown  Research & Development         High School
# 1   52        No        Unknown                 Unknown  College/University
# 2   42        No  travel_rarely  Research & Development       Middle School
# 3   47        No  travel_rarely  Research & Development  College/University
# 4   46        No        Unknown                   Sales         High School
#
#      Educationfield  Employeenumber Environmentsatisfaction  Gender  \
# 0           Unknown             162           Not Satisfied    Male
# 1     Life Sciences             259               Satisfied    Male
# 2  Technical Degree             319               Satisfied    Male
# 3           Medical            2069           Not Satisfied  Female
# 4  Technical Degree            2070           Not Satisfied  Female
#
#   Jobinvolvement   Joblevel            Jobrole Jobsatisfaction Maritalstatus  \
# 0           High  Executive  Research Director       Satisfied       Unknown
# 1       Moderate  Executive            Manager       Satisfied       Unknown
# 2           High  Executive            Manager  Very Satisfied       Married
# 3           High     Senior  Research Director       Satisfied       Married
# 4      Very High     Senior    Sales Executive   Not Satisfied      Divorced
#
#    Monthlyrate  Numcompaniesworked Overtime  Percentsalaryhike  \
# 0         6462                   7       No                 13
# 1         5678                   0  Unknown                 14
# 2         4933                   1       No                 11
# 3        26703                   3  Unknown                 19
# 4         7739                   2       No                 12
#
#   Relationshipsatisfaction  Stockoptionlevel  Trainingtimeslastyear  \
# 0                Satisfied                 0                      5
# 1            Not Satisfied                 1                      5
# 2           Very Satisfied                 0                      3
# 3       Somewhat Satisfied                 2                      2
# 4           Very Satisfied                 1                      5
#
#    Yearsatcompany  Yearssincelastpromotion  Yearswithcurrmanager  Datebirth  \
# 0              20                       15                    15       1972
# 1              33                       11                     9       1971
# 2              22                       11                    15       1981
# 3              20                        5                     6       1976
# 4              19                        2                     8       1977
#
#   Remotework  Dailyrate  Distancefromhome  Monthlyincome  Performancerating  \
# 0        Yes      684.0               6.0        19537.0                3.0
# 1        Yes      699.0               1.0        19999.0                3.0
# 2        Yes      532.0               4.0        19232.0                3.0
# 3         No      359.0               2.0        17169.0                3.0
# 4         No     1319.0               3.0         4884.6                3.0
#
#    Totalworkingyears  Worklifebalance  Hourlyrate
# 0               13.6              3.0        51.0
# 1               34.0              3.0        65.0
# 2               22.0              3.0        58.0
# 3               11.2              1.8        82.0
# 4               13.4              3.0        45.0

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'Businesstravel', 'Department', 'Education',
#        'Educationfield', 'Employeenumber', 'Environmentsatisfaction', 'Gender',
#        'Jobinvolvement', 'Joblevel', 'Jobrole', 'Jobsatisfaction',
#        'Maritalstatus', 'Monthlyrate', 'Numcompaniesworked', 'Overtime',
#        'Percentsalaryhike', 'Relationshipsatisfaction', 'Stockoptionlevel',
#        'Trainingtimeslastyear', 'Yearsatcompany', 'Yearssincelastpromotion',
#        'Yearswithcurrmanager', 'Datebirth', 'Remotework', 'Dailyrate',
#        'Distancefromhome', 'Monthlyincome', 'Performancerating',
#        'Totalworkingyears', 'Worklifebalance', 'Hourlyrate'],
#       dtype='object')

# %%
mediana_salario_hombres = df[df['Gender'] == 'Male']['Monthlyincome'].median()
mediana_salario_mujeres = df[df['Gender'] == 'Female']['Monthlyincome'].median()

# %%
mediana_salario_hombres = df[df['Gender'] == 'Male']['Monthlyincome'].median()
mediana_salario_mujeres = df[df['Gender'] == 'Female']['Monthlyincome'].median()
print(f"La mediana de salario para hombres es: {mediana_salario_hombres}")
print(f"La mediana de salario para mujeres es: {mediana_salario_mujeres}")
# Out:
# La mediana de salario para hombres es: 5336.2
# La mediana de salario para mujeres es: 5496.0

# %% [markdown]
# NEXT STEPS -- EXTRA a compara aparte de los requisitos:
#
# - Satisfiacción con el trabajo (Jobsatisfaction)
# - Environment satisfaction

# %% [markdown]
# Relación salario y años en la compañia

# %%
sns.scatterplot(x="Yearsatcompany", y="Monthlyincome", data=df, color="coral")

# Cambia las etiquetas de los ejes
plt.xlabel("Years at Company", fontsize=12)
plt.ylabel("Monthly Income", fontsize=12)

plt.title('Scatter Plot: Monthly Income vs. Years at Company', fontsize=14)

plt.show()

# %%
sns.regplot(x="Yearsatcompany", y="Monthlyincome", data=df, color="coral")

# Cambia las etiquetas de los ejes
plt.xlabel("Years at Company", fontsize=12)
plt.ylabel("Monthly Income", fontsize=12)

plt.title('Scatter Plot: Monthly Income vs. Years at Company', fontsize=14)

plt.show()

# %% [markdown]
# Comparamos años en la compañia y "rango" laboral

# %%
sns.barplot(x = "Yearsatcompany",
            y = "Joblevel",
            data = df,
            palette = "magma");

# %%
df.groupby("Joblevel")["Yearsatcompany"].mean()
# Out:
# Joblevel
# Entry-level     3.985586
# Executive      14.985714
# Junior          6.780220
# Mid-level       9.526316
# Senior         14.099099
# Name: Yearsatcompany, dtype: float64

# %%
media_por_grupo = df.groupby(["Joblevel", "Jobsatisfaction"]).mean()
media_por_grupo
# Out:
#                                       Age  Employeenumber   Monthlyrate  \
# Joblevel    Jobsatisfaction
# Entry-level Not Satisf
# Joblevel    Jobsatisfaction
# Entry-level Not Satisfied              2.709259   72.444444
#             Satisfied                  2.692121   64.482424
#             Somewhat Satisfied         2.724324   67.144144
#             Very Satisfied             2.646784   65.305263
# Executive   Not Satisfied              2.545455   77.109091
#             Satisfied                  2.984000   59.960000
#             Somewhat Satisfied         2.750000   73.162500
#             Very Satisfied             2.833333   60.222222
# Junior      Not Satisfied              2.776699   66.873786
#             Satisfied                  2.764848   67.264242
#             Somewhat Satisfied         2.801980   63.439604
#             Very Satisfied             2.719774   64.911864
# Mid-level   Not Satisfied              2.760000   65.272000
#             Satisfied                  2.835294   62.741176
#             Somewhat Satisfied         2.763158   66.473684
#             Very Satisfied             2.738889   62.016667
# Senior      Not Satisfied              2.652174   64.565217
#             Satisfied                  2.564286   63.907143
#             Somewhat Satisfied         2.800000   70.791667
#             Very Satisfied             2.755556   69.216667

# %%
satisfaccion_filtrada = df[df['Jobsatisfaction'].isin(['Satisfied', 'Very Satisfied'])]
grupo_por_joblevel = satisfaccion_filtrada.groupby('Joblevel').size()
print(grupo_por_joblevel)
# Out:
# Joblevel
# Entry-level    336
# Executive       43
# Junior         342
# Mid-level      140
# Senior          64
# dtype: int64

# %%
satisfaccion_filtrada2 = df[df['Jobsatisfaction'].isin(['Somewhat Satisfied', 'Not Satisfied'])]
grupo_por_joblevel = satisfaccion_filtrada2.groupby('Joblevel').size()
print(grupo_por_joblevel)
# Out:
# Joblevel
# Entry-level    219
# Executive       27
# Junior         204
# Mid-level       88
# Senior          47
# dtype: int64

# %%
df[df["Jobsatisfaction"]=="Very Satisfied"]
# Out:
#       Age Attrition Businesstravel              Department  \
# 2      42        No  travel_rarely  Research & Development
# 5      48        No        Unknown  Research & Development
# 21     33        No        Unknown  Research & Development
# 23     47        No        Unknown                 Unknown
# 24     36        No  travel_rarely                   Sales
# ...   ...       ...            ...                     ...
# 1600   55       Yes        Unknown                   Sales
# 1604   41       Yes        Unknown  Research & Development
# 1607   31        No        Unknown  Research & Development
# 1609   36       Yes  travel_rarely                   Sales
# 1612   36        No     non-travel                   Sales
#
#                Education    Educationfield  Employeenumber  \
# 2          Middle School  Technical Degree             319
# 5            High School           Medical            1900
# 21         Middle School     Life Sciences              73
# 23         Middle School             Other             820
# 24         Middle School     Life Sciences            2079
# ...                  ...               ...             ...
# 1600   Elementary School           Medical             842
# 1604  College/University     Life Sciences             927
# 1607         High School           Medical            2497
# 1609   Elementary School     Life Sciences             967
# 1612  College/University  Technical Degree             990
#
#      Environmentsatisfaction  Gender Jobinvolvement     Joblevel  \
# 2                  Satisfied    Male           High    Executive
# 5             Very Satisfied  Female           High       Senior
# 21             Not Satisfied  Female           High    Mid-level
# 23                 Satisfied  Female           High       Senior
# 24            Very Satisfied    Male           High       Junior
# ...                      ...     ...            ...          ...
# 1600               Satisfied    Male           High       Junior
# 1604      Somewhat Satisfied  Female            Low  Entry-level
# 1607          Very Satisfied  Female           High       Junior
# 1609               Satisfied    Male       Moderate    Mid-level
# 1612           Not Satisfied    Male           High       Junior
#
#                         Jobrole Jobsatisfaction Maritalstatus  Monthlyrate  \
# 2                       Manager  Very Satisfied       Married         4933
# 5                       Manager  Very Satisfied       Unknown         2437
# 21            Research Director  Very Satisfied        Single        15146
# 23                      Manager  Very Satisfied       Married        12982
# 24              Sales Executive  Very Satisfied       Unknown         2823
# ...                         ...             ...           ...          ...
# 1600            Sales Executive  Very Satisfied        Single        21519
# 1604      Laboratory Technician  Very Satisfied      Divorced        17725
# 1607  Healthcare Representative  Very Satisfied       Unknown        17369
# 1609            Sales Executive  Very Satisfied       Married         5518
# 1612            Sales Executive  Very Satisfied      Divorced        25952
#
#       Numcompaniesworked Overtime  Percentsalaryhike Relationshipsatisfaction  \
# 2                      1       No                 11           Very Satisfied
# 5                      3       No                 11       Somewhat Satisfied
# 21                     1      Yes                 12                Satisfied
# 23                     1  Unknown                 11                Satisfied
# 24                     1  Unknown                 14           Very Satisfied
# ...                  ...      ...                ...                      ...
# 1600                   4  Unknown                 16                Satisfied
# 1604                   4      Yes                 13                Satisfied
# 1607                   0  Unknown                 11                Satisfied
# 1609                   1  Unknown                 11            Not Satisfied
# 1612                   4       No                 13           Very Satisfied
#
#       Stockoptionlevel  Trainingtimeslastyear  Yearsatcompany  \
# 2                    0                      3              22
# 5                    1                      3              22
# 21                   0                      1              15
# 23                   1                      3              26
# 24                   1                      1              18
# ...                ...                    ...             ...
# 1600                 0                      3               9
# 1604                 1                      1               7
# 1607                 2                      2               9
# 1609                 1                      6              16
# 1612                 2                      3               7
#
#       Yearssincelastpromotion  Yearswithcurrmanager  Datebirth Remotework  \
# 2                          11                    15       1981        Yes
# 5                           4                     7       1975        Yes
# 21                          8                    12       1990        Yes
# 23                          3                     0       1976         No
# 24                          4                    11       1987        Yes
# ...                       ...                   ...        ...        ...
# 1600                        7                     3       1968        Yes
# 1604                        1                     0       1982        Yes
# 1607                        8                     5       1992        Yes
# 1609                        3                     7       1987         No
# 1612                        0                     7       1987        Yes
#
#       Dailyrate  Distancefromhome  Monthlyincome  Performancerating  \
# 2         532.0               4.0        19232.0                3.0
# 5         117.0              22.0        17174.0                3.0
# 21        515.0               1.0         5537.6                3.0
# 23        202.0               2.0        16752.0                3.0
# 24        928.0              10.2         6201.0                3.0
# ...         ...               ...            ...                ...
# 1600      436.0               2.0         7416.2                3.0
# 1604     1085.0               2.0        12335.8                3.0
# 1607      616.0              12.0         5665.2                3.0
# 1609      530.0               3.0        10325.0                3.4
# 1612     1229.0               8.0         5839.8                3.0
#
#       Totalworkingyears  Worklifebalance  Hourlyrate
# 2                  22.0              3.0        58.0
# 5                  14.4              3.0        58.0
# 21                 15.0              3.0        98.0
# 23                 14.0              2.0        33.0
# 24                 18.0              3.0        56.0
# ...                 ...              ...         ...
# 1600               16.8              2.0        37.0
# 1604               20.6              2.0        63.8
# 1607               10.0              1.0        41.0
# 1609               16.8              3.0        51.0
# 1612               12.0              3.0        84.0
#
# [474 rows x 33 columns]

# %% [markdown]
# Satisfacción y joblevel

# %%
sns.countplot(x='Jobsatisfaction', data=df, palette='viridis') 
plt.title('Gráfico de barras de satisfacción laboral')
plt.xlabel('Satisfacción laboral')
plt.ylabel('Frecuencia')
plt.show()

# %%
df["Department"].value_counts()
# Out:
# Research & Development    945
# Sales                     425
# Unknown                    86
# Human Resources            54
# Name: Department, dtype: int64
