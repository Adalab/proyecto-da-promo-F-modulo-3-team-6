# %% [markdown]
# # SESION 4 DICIEMBRE

# %% [markdown]
# # Modificamos columnas que eran object a float

# %%
import pandas as pd
import numpy as np
# -----------------------------------------------------------------------
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# Librerías de visualización
# -----------------------------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df_rawdata = pd.read_csv("../Data/raw_data_20231201.csv", index_col=0)

# %%
def cambiar_comas(cadena):
    try:
        return float(cadena.replace(",", "."))
    except:
        return np.nan
    
df_rawdata["Monthlyincome"] = df_rawdata["Monthlyincome"].apply(cambiar_comas)
df_rawdata["Performancerating"] = df_rawdata["Performancerating"].apply(cambiar_comas)
df_rawdata["Totalworkingyears"] = df_rawdata["Totalworkingyears"].apply(cambiar_comas)

# %%
df_rawdata["Employeenumber"]= df_rawdata["Employeenumber"].apply(cambiar_comas)

# %%
df_rawdata["Employeenumber"].isnull().sum()
# Out:
# 431

# %% [markdown]
# # Gestión de nulos

# %% [markdown]
# Cambiamos los nulos de Employeenumber con un "auto-incremental"

# %%
# Encuentra el último ID existente
ultimo_id = df_rawdata['Employeenumber'].max()
# Define una variable para el siguiente ID después del último
siguiente_id = ultimo_id + 1
# Itera sobre los índices del DataFrame
for indice in df_rawdata.index:
    if pd.isnull(df_rawdata.at[indice, 'Employeenumber']):  # Verifica si el valor es nulo
        df_rawdata.at[indice, 'Employeenumber'] = siguiente_id  # Asigna el siguiente ID
        siguiente_id += 1  # Incrementa el siguiente ID
df_rawdata["Employeenumber"] = df_rawdata["Employeenumber"].astype(int)
# Muestra el DataFrame actualizado
print(df_rawdata["Employeenumber"].tail(10))
# Out:
# 1604     927
# 1605     941
# 1606     956
# 1607    2497
# 1608     966
# 1609     967
# 1610     972
# 1611    2498
# 1612     990
# 1613    2499
# Name: Employeenumber, dtype: int64

# %%
# Muestra el DataFrame actualizado
df_rawdata["Employeenumber"].dtype
# Out:
# dtype('int64')

# %%
nulls_cat = df_rawdata[df_rawdata.columns[df_rawdata.isnull().any()]].select_dtypes(include = "O").columns
nulls_cat
# Out:
# Index(['Businesstravel', 'Department', 'Educationfield', 'Maritalstatus',
#        'Overtime'],
#       dtype='object')

# %%
(df_rawdata[['Businesstravel', 'Department', 'Educationfield', 'Maritalstatus','Overtime']].isnull().sum() / df_rawdata.shape[0]) * 100
# Out:
# Businesstravel    47.880795
# Department        81.258278
# Educationfield    46.490066
# Maritalstatus     40.264901
# Overtime          41.721854
# dtype: float64

# %%
# sacamos el 'value_counts()' de cada una de las columnas categóricas que tienen nulos para saber como es la distribución de sus categorías
for col in nulls_cat:
    print(f"La distribución de las categorías para la columna {col.upper()}")
    display(df_rawdata[col].value_counts() / df_rawdata.shape[0])
    print("........................")
# Out:
# La distribución de las categorías para la columna BUSINESSTRAVEL
# Businesstravel
# travel_rarely        0.364901
# travel_frequently    0.101325
# non-travel           0.054967
# Name: count, dtype: float64
# ........................
# La distribución de las categorías para la columna DEPARTMENT
# Department
#  Research & Development     0.122517
#  Sales                      0.055629
#  Human Resources            0.009272
# Name: count, dtype: float64
# ........................
# La distribución de las categorías para la columna EDUCATIONFIELD
# Educationfield
# Life Sciences       0.215894
# Medical             0.169536
# Marketing           0.064238
# Technical Degree    0.042384
# Other               0.035762
# Human Resources     0.007285
# Name: count, dtype: float64
# ........................
# La distribución de las categorías para la columna MARITALSTATUS
# Maritalstatus
# Married     0.270861
# Single      0.202649
# Divorced    0.123841
# Name: count, dtype: float64
# ........................
# La distribución de las categorías para la columna OVERTIME
# Overtime
# No     0.422517
# Yes    0.160265
# Name: count, dtype: float64
# ........................

# %%
nulls_cat = ['Businesstravel', 'Educationfield', 'Maritalstatus', 'Overtime']

# %% [markdown]
# Todos desconocidos!

# %%
for columna in nulls_cat:
    # reemplazamos los nulos por el valor Unknown para cada una de las columnas de la lista
    df_rawdata[columna] = df_rawdata[columna].fillna("Unknown")

# %%
df_rawdata["Overtime"].unique()
# Out:
# array(['No', 'Unknown', 'Yes'], dtype=object)

# %% [markdown]
# # Columna Department: vinculada con Jobrole

# %%
# primero vemos cómo está la columna Jobrole
#df_rawdata["Jobrole"].head()

# %%
# # capitalize valores de Jobrole (primera letra de cada palabra)
# df_rawdata['Jobrole'] = df_rawdata['Jobrole'].apply(lambda x: ' '.join(word.capitalize() for word in x.lower().split()))
# df_rawdata["Jobrole"].head()

# %%
# hacemos función para asignar los valores nulos en Department según la columna Jobrole
def fill_department(df, jobrole, department):
    df.loc[df['Jobrole'] == jobrole, 'Department'] = df.loc[df['Jobrole'] == jobrole, 'Department'].fillna(department)

# Uso de la función fill_department para reemplazar los valores faltantes en 'Department'
fill_department(df_rawdata, 'Research Director', 'Research & Development')
fill_department(df_rawdata, 'Healthcare Representative', 'Research & Development')
fill_department(df_rawdata, 'Laboratory Technician', 'Research & Development')
fill_department(df_rawdata, 'Manufacturing Director', 'Research & Development')
fill_department(df_rawdata, 'Research Scientist', 'Research & Development')
fill_department(df_rawdata, 'Sales Executive', 'Sales')
fill_department(df_rawdata, 'Sales Representative', 'Sales')
fill_department(df_rawdata, 'Human Resources', 'Human Resources')
fill_department(df_rawdata, 'Manager', 'Unknown')

df_rawdata["Department"] = df_rawdata["Department"].str.strip()
# Mostrar el DataFrame actualizado
df_rawdata[["Jobrole", "Department"]].head(5)
# Out:
#                Jobrole              Department
# 0   Research Director                      NaN
# 1             Manager                      NaN
# 2             Manager   Research & Development
# 3   Research Director                      NaN
# 4     Sales Executive                      NaN

# %%
# Mostrar estadísticas descriptivas y conteo de valores únicos
print("Estadísticas descriptivas para 'Jobrole':\n", df_rawdata['Jobrole'].describe())
print("\nEstadísticas descriptivas para 'Department':\n", df_rawdata['Department'].describe())

print("\nConteo de valores únicos para 'Jobrole':\n", df_rawdata['Jobrole'].value_counts())
print("\nConteo de valores únicos para 'Department':\n", df_rawdata['Department'].value_counts())
# Out:
# Estadísticas descriptivas para 'Jobrole':
#  count                  1510
# unique                    9
# top        Sales Executive
# freq                    336
# Name: Jobrole, dtype: object
#
# Estadísticas descriptivas para 'Department':
#  count                        283
# unique                         3
# top       Research & Development
# freq                         185
# Name: Department, dtype: object
#
# Conteo de valores únicos para 'Jobrole':
#  Jobrole
#  Sales Executive               336
#  Research Scientist            300
#  Laboratory Technician         264
#  Manufacturing Director        148
#  Healthcare Representative     137
#  Manager                       105
#  Sales Representative           84
#  Research Director              83
#  Human Resources                53
# Name: count, dtype: int64
#
# Conteo de valores únicos para 'Department':
#  Department
# Research & Development    185
# Sales                      84
# Human Resources            14
# Name: count, dtype: int64

# %% [markdown]
# # Todas las columnas categóricas listas

# %%
# Como hay valores negativos en la columna Distancefromhome los cambiamos a nulos.
def negative_to_null(data):
    if data < 0:
        return np.nan
    else:
        return data
    
df_rawdata["Distancefromhome"] = df_rawdata["Distancefromhome"].apply(negative_to_null)

# %%
df_rawdata["Distancefromhome"].tail(5)
# Out:
# 1609    3.0
# 1610    4.0
# 1611    NaN
# 1612    8.0
# 1613    7.0
# Name: Distancefromhome, dtype: float64

# %% [markdown]
# ## Gestión nulos columnas numéricas

# %%
nulls_num = df_rawdata[df_rawdata.columns[df_rawdata.isna().any()]].columns
nulls_num
# Out:
# Index(['Dailyrate', 'Department', 'Distancefromhome', 'Monthlyincome',
#        'Performancerating', 'Totalworkingyears', 'Worklifebalance'],
#       dtype='object')

# %%
# Función para quitar "Not Available" y poner nulos en su lugar
def not_available_to_null(data):
    if data == 'Not Available':
        return np.nan
    else:
        return float(data)
df_rawdata["Hourlyrate"] = df_rawdata["Hourlyrate"].apply(not_available_to_null)

# %%
df_rawdata_copy = df_rawdata.copy()

# %%
print(f"Tenemos nulos: \n{df_rawdata_copy[['Dailyrate', 'Distancefromhome', 'Monthlyincome', 'Performancerating','Totalworkingyears', 'Worklifebalance', 'Hourlyrate']].isnull().sum()} nulos")
# Out:
# Tenemos nulos:
# Dailyrate            116
# Distancefromhome     178
# Monthlyincome        799
# Performancerating    182
# Totalworkingyears    494
# Worklifebalance      100
# Hourlyrate            80
# dtype: int64 nulos

# %% [markdown]
# # IterativeImputer

# %%
# instanciamos las clases										
imputer_iterative = IterativeImputer(max_iter = 20, random_state = 42)			
# ajustamos y tranformamos los datos										
imputer_iterative_imputado = imputer_iterative.fit_transform(df_rawdata_copy[['Dailyrate', 'Distancefromhome', 'Monthlyincome', 'Performancerating','Totalworkingyears', 'Worklifebalance', 'Hourlyrate']])
# comprobamos que es lo que nos devuelve, que en este caso es un array también					
imputer_iterative_imputado
# Out:
# array([[6.84000000e+02, 6.00000000e+00, 1.95370000e+04, ...,
#         3.26175277e+01, 3.00000000e+00, 5.10000000e+01],
#        [6.99000000e+02, 1.00000000e+00, 1.99990000e+04, ...,
#         3.40000000e+01, 3.00000000e+00, 6.50000000e+01],
#        [5.32000000e+02, 4.00000000e+00, 1.92320000e+04, ...,
#         2.20000000e+01, 2.90522101e+00, 5.80000000e+01],
#        ...,
#        [9.03000000e+02, 9.05859584e+00, 4.96921235e+03, ...,
#         9.00000000e+00, 3.00000000e+00, 4.10000000e+01],
#        [1.22900000e+03, 8.00000000e+00, 6.38325083e+03, ...,
#         1.20000000e+01, 3.00000000e+00, 8.40000000e+01],
#        [5.66000000e+02, 7.00000000e+00, 1.08450000e+04, ...,
#         1.84083797e+01, 3.00000000e+00, 7.50000000e+01]])

# %%
df_rawdata_copy[['Dailyrate_ITE', 'Distancefromhome_ITE', 'Monthlyincome_ITE', 'Performancerating_ITE','Totalworkingyears_ITE', 'Worklifebalance_ITE', 'Hourlyrate_ITE']] = imputer_iterative_imputado										
										
# comprobamos los nulos										
print(f"Después del 'Iterative' tenemos: \n{df_rawdata_copy[['Dailyrate_ITE', 'Distancefromhome_ITE', 'Monthlyincome_ITE', 'Performancerating_ITE', 'Totalworkingyears_ITE', 'Worklifebalance_ITE', 'Hourlyrate_ITE']].isnull().sum()} nulos")
# Out:
# Después del 'Iterative' tenemos:
# Dailyrate_ITE            0
# Distancefromhome_ITE     0
# Monthlyincome_ITE        0
# Performancerating_ITE    0
# Totalworkingyears_ITE    0
# Worklifebalance_ITE      0
# Hourlyrate_ITE           0
# dtype: int64 nulos

# %% [markdown]
# # KNN Imputer

# %%
# instanciamos la clase del KNNImputer
imputer_knn = KNNImputer(n_neighbors = 5)
# ajustamos y transformamos los datos
imputer_knn_imputado = imputer_knn.fit_transform(df_rawdata_copy[['Dailyrate', 'Distancefromhome', 'Monthlyincome', 'Performancerating','Totalworkingyears', 'Worklifebalance', 'Hourlyrate']])
# comprobamos que es lo que nos devuelve, que sigue siendo un array
imputer_knn_imputado
# Out:
# array([[6.8400e+02, 6.0000e+00, 1.9537e+04, ..., 1.3600e+01, 3.0000e+00,
#         5.1000e+01],
#        [6.9900e+02, 1.0000e+00, 1.9999e+04, ..., 3.4000e+01, 3.0000e+00,
#         6.5000e+01],
#        [5.3200e+02, 4.0000e+00, 1.9232e+04, ..., 2.2000e+01, 3.0000e+00,
#         5.8000e+01],
#        ...,
#        [9.0300e+02, 1.0600e+01, 7.1448e+03, ..., 9.0000e+00, 3.0000e+00,
#         4.1000e+01],
#        [1.2290e+03, 8.0000e+00, 5.8398e+03, ..., 1.2000e+01, 3.0000e+00,
#         8.4000e+01],
#        [5.6600e+02, 7.0000e+00, 1.0845e+04, ..., 1.5000e+01, 3.0000e+00,
#         7.5000e+01]])

# %%
# por último nos queda añadir ese array al DataFrame como hemos hecho hasta ahora
df_rawdata_copy[['Dailyrate_KNN', 'Distancefromhome_KNN', 'Monthlyincome_KNN', 'Performancerating_KNN','Totalworkingyears_KNN', 'Worklifebalance_KNN', 'Hourlyrate_KNN']] = imputer_knn_imputado

# comprobamos los nulos
print(f"Después del 'KNN' tenemos: \n{df_rawdata_copy[['Dailyrate_KNN', 'Distancefromhome_KNN', 'Monthlyincome_KNN', 'Performancerating_KNN','Totalworkingyears_KNN', 'Worklifebalance_KNN', 'Hourlyrate_KNN']].isnull().sum()} nulos")
# Out:
# Después del 'KNN' tenemos:
# Dailyrate_KNN            0
# Distancefromhome_KNN     0
# Monthlyincome_KNN        0
# Performancerating_KNN    0
# Totalworkingyears_KNN    0
# Worklifebalance_KNN      0
# Hourlyrate_KNN           0
# dtype: int64 nulos

# %%
df_rawdata_copy.describe()[['Dailyrate', 'Dailyrate_ITE', 'Dailyrate_KNN']]
# Out:
#          Dailyrate  Dailyrate_ITE  Dailyrate_KNN
# count  1394.000000    1510.000000    1510.000000
# mean    807.050215     807.859002     811.300662
# std     401.842182     386.577732     388.916129
# min     103.000000     103.000000     103.000000
# 25%     472.500000     504.250000     501.750000
# 50%     805.500000     807.451017     814.000000
# 75%    1157.750000    1135.500000    1137.750000
# max    1499.000000    1499.000000    1499.000000

# %%
df_rawdata_copy.describe()[["Distancefromhome", "Distancefromhome_ITE", "Distancefromhome_KNN"]]
# Out:
#        Distancefromhome  Distancefromhome_ITE  Distancefromhome_KNN
# count       1332.000000           1510.000000           1510.000000
# mean           8.960961              8.964555              9.123974
# std            7.954886              7.471860              7.571923
# min            1.000000              1.000000              1.000000
# 25%            2.000000              2.000000              2.000000
# 50%            7.000000              8.000000              7.700000
# 75%           13.000000             11.000000             13.000000
# max           29.000000             29.000000             29.000000

# %%
df_rawdata_copy.describe()[["Monthlyincome", "Monthlyincome_ITE", "Monthlyincome_KNN"]]
# Out:
#        Monthlyincome  Monthlyincome_ITE  Monthlyincome_KNN
# count     711.000000        1510.000000        1510.000000
# mean     6527.918425        6379.350669        6210.313775
# std      4810.541121        4045.555183        3600.306711
# min      1009.000000        -440.442943        1009.000000
# 25%      2906.500000        3527.203958        3958.150000
# 50%      4850.000000        5477.298448        5417.000000
# 75%      8456.000000        7423.212705        7260.200000
# max     19999.000000       21083.516020       19999.000000

# %%
df_rawdata_copy.describe()[["Performancerating", "Performancerating_ITE", "Performancerating_KNN"]]
# Out:
#        Performancerating  Performancerating_ITE  Performancerating_KNN
# count        1328.000000            1510.000000            1510.000000
# mean            3.155120               3.155151               3.155762
# std             0.362156               0.339627               0.343147
# min             3.000000               3.000000               3.000000
# 25%             3.000000               3.000000               3.000000
# 50%             3.000000               3.000000               3.000000
# 75%             3.000000               3.141685               3.000000
# max             4.000000               4.000000               4.000000

# %%
df_rawdata_copy.describe()[["Totalworkingyears","Totalworkingyears_ITE", "Totalworkingyears_KNN"]]
# Out:
#        Totalworkingyears  Totalworkingyears_ITE  Totalworkingyears_KNN
# count        1016.000000            1510.000000            1510.000000
# mean           11.314961              11.551796              12.370861
# std             7.794100               7.223500               6.803500
# min             0.000000               0.000000               0.000000
# 25%             6.000000               6.970660               8.000000
# 50%            10.000000              10.000000              12.000000
# 75%            15.000000              13.973624              16.000000
# max            40.000000              40.000000              40.000000

# %%
df_rawdata_copy.describe()[["Worklifebalance", "Worklifebalance_ITE", "Worklifebalance_KNN"]]
# Out:
#        Worklifebalance  Worklifebalance_ITE  Worklifebalance_KNN
# count      1410.000000          1510.000000          1510.000000
# mean          2.756028             2.755562             2.733907
# std           0.705888             0.682206             0.692784
# min           1.000000             1.000000             1.000000
# 25%           2.000000             2.000000             2.000000
# 50%           3.000000             3.000000             3.000000
# 75%           3.000000             3.000000             3.000000
# max           4.000000             4.000000             4.000000

# %%
df_rawdata_copy.describe()[["Hourlyrate","Hourlyrate_ITE","Hourlyrate_KNN"]]
# Out:
#         Hourlyrate  Hourlyrate_ITE  Hourlyrate_KNN
# count  1430.000000     1510.000000     1510.000000
# mean     66.025175       66.025926       65.930728
# std      20.270996       19.727124       19.792448
# min      30.000000       30.000000       30.000000
# 25%      48.000000       49.000000       49.000000
# 50%      66.000000       66.000000       66.000000
# 75%      84.000000       83.000000       83.000000
# max     100.000000      100.000000      100.000000

# %% [markdown]
# Dailyrate_KNN, Distancefromhome_KNN, Monthlyincome_KNN, Performancerating_KNN, Totalworkingyears_KNN, Worklifebalance_KNN, Hourlyrate_KNN
#
# # Hemos seleccionado el método KNN Imputer ya que los resultados son más precisos.

# %%
#al final me quedo con las del método kn por escoger alguna
df_rawdata_copy.drop(['Dailyrate', 'Dailyrate_ITE', 'Distancefromhome', 'Distancefromhome_ITE', 'Monthlyincome', 'Monthlyincome_ITE', 'Performancerating', 'Performancerating_ITE', 'Totalworkingyears', 'Totalworkingyears_ITE', 'Worklifebalance', 'Worklifebalance_ITE', 'Hourlyrate', 'Hourlyrate_ITE'], axis = 1, inplace = True)

# ahora vamos a cambiar el nombre de las columnas que quedaron para que tengan el mismo nombre de origen
nuevo_nombre = {"Dailyrate_KNN": "Dailyrate",  'Distancefromhome_KNN': "Distancefromhome", "Monthlyincome_KNN": "Monthlyincome", "Performancerating_KNN": "Performancerating","Totalworkingyears_KNN": "Totalworkingyears", "Worklifebalance_KNN": "Worklifebalance", "Hourlyrate_KNN":"Hourlyrate"}
df_rawdata_copy.rename(columns = nuevo_nombre, inplace = True)

# %%
df_rawdata_copy.columns
# Out:
# Index(['Age', 'Attrition', 'Businesstravel', 'Department', 'Education',
#        'Educationfield', 'Employeenumber', 'Environmentsatisfaction', 'Gender',
#        'Jobinvolvement', 'Joblevel', 'Jobrole', 'Jobsatisfaction',
#        'Maritalstatus', 'Monthlyrate', 'Numcompaniesworked', 'Overtime',
#        'Percentsalaryhike', 'Relationshipsatisfaction', 'Stockoptionlevel',
#        'Trainingtimeslastyear', 'Yearsatcompany', 'Yearssincelastpromotion',
#        'Yearswithcurrmanager', 'Datebirth', 'Remotework', 'Dailyrate',
#        'Distancefromhome', 'Monthlyincome', 'Performancerating',
#        'Totalworkingyears', 'Worklifebalance', 'Hourlyrate'],
#       dtype='object')

# %%
df_rawdata_copy.to_csv("../Data/raw_data_final_20231205.csv")

# %% [markdown]
# # Sesión 12 diciembre

# %%
df_rawdata_copy= pd.read_csv("../Data/raw_data_final_20231205.csv", index_col=0)

# %% [markdown]
# Hemos cambiado los datos numericos de la variable Jobinvolvement por etiquetas

# %%
dict_map = {1.0: "Low", 2.0: "Moderate", 3.0: "High", 4.0: "Very High"}
df_rawdata_copy["Jobinvolvement"] = df_rawdata_copy["Jobinvolvement"].replace(dict_map)

# %%
df_rawdata_copy["Jobinvolvement"].value_counts()
# Out:
# Jobinvolvement
# High         891
# Moderate     383
# Very High    152
# Low           84
# Name: count, dtype: int64

# %% [markdown]
# ### Pasamos a la columna Jobrole

# %%
# primero vemos cómo está la columna Jobrole
df_rawdata_copy["Jobrole"].head()
# Out:
# 0     Research Director
# 1               Manager
# 2               Manager
# 3     Research Director
# 4       Sales Executive
# Name: Jobrole, dtype: object

# %%
# capitalize valores de Jobrole (primera letra de cada palabra)
df_rawdata_copy['Jobrole'] = df_rawdata_copy['Jobrole'].apply(lambda x: ' '.join(word.capitalize() for word in x.lower().split()))
df_rawdata_copy["Jobrole"].head()
# Out:
# 0    Research Director
# 1              Manager
# 2              Manager
# 3    Research Director
# 4      Sales Executive
# Name: Jobrole, dtype: object

# %% [markdown]
# Aplicamos los cambios en Department mediante una función:

# %%
def fill_department(df, jobrole, department):
    df.loc[df['Jobrole'] == jobrole, 'Department'] = df.loc[df['Jobrole'] == jobrole, 'Department'].fillna(department)
    return df

# Uso de la función fill_department para reemplazar los valores faltantes en 'Department'
df_rawdata_copy=fill_department(df_rawdata_copy, 'Research Director', 'Research & Development')
df_rawdata_copy=fill_department(df_rawdata_copy, 'Healthcare Representative', 'Research & Development')
df_rawdata_copy=fill_department(df_rawdata_copy, 'Laboratory Technician', 'Research & Development')
df_rawdata_copy=fill_department(df_rawdata_copy, 'Manufacturing Director', 'Research & Development')
df_rawdata_copy=fill_department(df_rawdata_copy, 'Research Scientist', 'Research & Development')
df_rawdata_copy=fill_department(df_rawdata_copy, 'Sales Executive', 'Sales')
df_rawdata_copy=fill_department(df_rawdata_copy, 'Sales Representative', 'Sales')
df_rawdata_copy=fill_department(df_rawdata_copy, 'Human Resources', 'Human Resources')
df_rawdata_copy=fill_department(df_rawdata_copy, 'Manager', 'Unknown')

df_rawdata_copy["Department"] = df_rawdata_copy["Department"].str.strip()
# Mostrar el DataFrame actualizado
df_rawdata_copy[["Jobrole", "Department"]].head(5)
# Out:
#              Jobrole              Department
# 0  Research Director  Research & Development
# 1            Manager                 Unknown
# 2            Manager  Research & Development
# 3  Research Director  Research & Development
# 4    Sales Executive                   Sales

# %%
df_rawdata_copy
# Out:
#       Age Attrition     Businesstravel              Department  Education  \
# 0      51        No            Unknown  Research & Development          3
# 1      52        No            Unknown                 Unknown          4
# 2      42        No      travel_rarely  Research & Development          2
# 3      47        No      travel_rarely  Research & Development          4
# 4      46        No            Unknown                   Sales          3
# 5      48        No            Unknown  Research & Development          3
# 6      59        No            Unknown                   Sales          3
# 7      42        No      travel_rarely                   Sales          1
# 8      41        No            Unknown                 Unknown          5
# 9      41        No  travel_frequently  Research & Development          3
# 10     41        No         non-travel  Research & Development          1
# 11     56        No      travel_rarely  Research & Development          3
# 12     38        No            Unknown  Research & Development          3
# 13     41       Yes      travel_rarely  Research & Development          3
# 14     55        No            Unknown  Research & Development          4
# 15     40        No      travel_rarely                 Unknown          4
# 16     58       Yes      travel_rarely  Research & Development          4
# 17     46        No      travel_rarely                 Unknown          3
# 18     35        No            Unknown  Research & Development          5
# 19     40        No      travel_rarely  Research & Development          3
# 20     45        No         non-travel  Research & Development          1
# 21     33        No            Unknown  Research & Development          2
# 22     36        No            Unknown  Research & Development          3
# 23     47        No            Unknown                 Unknown          2
# 24     36        No      travel_rarely                   Sales          2
# 25     35        No            Unknown  Research & Development          3
# 26     52       Yes            Unknown                 Unknown          1
# 27     36        No            Unknown  Research & Development          4
# 28     33        No      travel_rarely  Research & Development          4
# 29     34        No         non-travel                   Sales          3
# 30     41        No            Unknown                   Sales          1
# 31     47        No            Unknown  Research & Development          3
# 32     53        No      travel_rarely                 Unknown          3
# 33     35        No            Unknown                   Sales          4
# 34     34        No      travel_rarely  Research & Development          4
# 35     46        No      travel_rarely                   Sales          2
# 36     43        No            Unknown                 Unknown          3
# 37     36        No            Unknown  Research & Development          3
# 38     60        No  travel_frequently                   Sales          3
# 39     40        No  travel_frequently                   Sales          4
# 40     32        No      travel_rarely  Research & Development          3
# 41     41        No      travel_rarely  Research & Development          3
# 42     53        No            Unknown                 Unknown          2
# 43     36       Yes      travel_rarely  Research & Development          4
# 44     46        No            Unknown  Research & Development          4
# 45     38        No      travel_rarely                   Sales          4
# 46     51        No            Unknown  Research & Development          4
# 47     43        No            Unknown                 Unknown          2
# 48     37        No            Unknown  Research & Development          3
# 49     32        No      travel_rarely                   Sales          2
# 50     38        No            Unknown  Research & Development          3
# 51     46        No            Unknown                 Unknown          3
# 52     35       Yes      travel_rarely                   Sales          3
# 53     43        No            Unknown                 Unknown          3
# 54     56        No         non-travel  Research & Development          4
# 55     36        No         non-travel                   Sales          4
# 56     38        No            Unknown  Research & Development          3
# 57     49        No            Unknown  Research & Development          4
# 58     39        No      travel_rarely                   Sales          4
# 59     40        No            Unknown                   Sales          4
# 60     36        No            Unknown  Research & Development          2
# 61     37        No            Unknown  Research & Development          5
# 62     35        No            Unknown  Research & Development          4
# 63     33        No  travel_frequently  Research & Development          3
# 64     50        No      travel_rarely  Research & Development          3
# 65     48        No      travel_rarely  Research & Development          4
# 66     44        No      travel_rarely                   Sales          3
# 67     44        No      travel_rarely  Research & Development          4
# 68     40        No            Unknown  Research & Development          1
# 69     34        No      travel_rarely  Research & Development          4
# 70     35        No         non-travel  Research & Development          4
# 71     50        No            Unknown  Research & Development          5
# 72     49        No            Unknown  Research & Development          1
# 73     38        No  travel_frequently  Research & Development          3
# 74     33        No            Unknown  Research & Development          3
# 75     47        No      travel_rarely  Research & Development          3
# 76     38        No            Unknown  Research & Development          3
# 77     37        No      travel_rarely  Research & Development          3
# 78     30        No            Unknown  Research & Development          3
# 79     58        No      travel_rarely                   Sales          4
# 80     34        No      travel_rarely                 Unknown          3
# 81     58       Yes      travel_rarely  Research & Development          4
# 83     29        No  travel_frequently                   Sales          1
# 85     41        No            Unknown                 Unknown          4
# 86     39        No      travel_rarely  Research & Development          3
# 87     38        No            Unknown  Research & Development          2
# 88     43        No            Unknown  Research & Development          3
# 91     35        No            Unknown  Research & Development          3
# 92     47        No            Unknown  Research & Development          4
# 93     35        No            Unknown  Research & Development          4
# 94     40        No      travel_rarely  Research & Development          4
# 95     45        No            Unknown                   Sales          4
# 96     33        No            Unknown  Research & Development          3
# 97     36        No  travel_frequently  Research & Development          3
# 98     45       Yes            Unknown                 Unknown          3
# 99     51        No  travel_frequently                 Unknown          3
# 101    43        No      travel_rarely  Research & Development          2
# 102    34        No            Unknown  Research & Development          2
# 103    38        No            Unknown         Human Resources          3
# 104    48        No            Unknown  Research & Development          3
# 105    34        No            Unknown  Research & Development          4
# 106    32        No      travel_rarely                   Sales          4
# 107    29        No      travel_rarely  Research & Development          4
# 108    46        No            Unknown  Research & Development          3
# 109    30        No            Unknown         Human Resources          3
# 110    45        No            Unknown  Research & Development          3
# 111    30        No      travel_rarely                   Sales          3
# 112    30        No            Unknown  Research & Development          3
# 113    34        No  travel_frequently  Research & Development          1
# 114    51        No      travel_rarely  Research & Development          4
# 115    34        No            Unknown  Research & Development          4
# 116    35        No      travel_rarely                   Sales          3
# 117    45        No  travel_frequently  Research & Development          3
# 118    39        No            Unknown                 Unknown          1
# 119    31        No            Unknown  Research & Development          2
# 120    39        No            Unknown  Research & Development          2
# 121    45        No      travel_rarely  Research & Development          4
# 122    30        No      travel_rarely                   Sales          3
# 123    31        No            Unknown  Research & Development          4
# 124    36        No            Unknown                   Sales          4
# 125    36        No      travel_rarely                   Sales          2
# 126    55        No      travel_rarely                 Unknown          5
# 127    35        No            Unknown                   Sales          3
# 128    42        No      travel_rarely  Research & Development          3
# 129    52        No      travel_rarely  Research & Development          2
# 130    49        No            Unknown  Research & Development          4
# 131    34        No      travel_rarely  Research & Development          5
# 132    33       Yes      travel_rarely  Research & Development          4
# 133    33        No            Unknown  Research & Development          3
# 134    53        No      travel_rarely  Research & Development          4
# 135    49        No      travel_rarely  Research & Development          2
# 136    35        No            Unknown                   Sales          4
# 137    38        No      travel_rarely  Research & Development          1
# 138    46        No            Unknown                   Sales          1
# 139    36        No         non-travel  Research & Development          4
# 140    42       Yes  travel_frequently                   Sales          3
# 141    34        No  travel_frequently  Research & Development          3
# 142    30        No      travel_rarely  Research & Development          3
# 143    54        No      travel_rarely  Research & Development          3
# 144    31        No      travel_rarely  Research & Development          3
# 145    44        No            Unknown                 Unknown          3
# 146    55        No         non-travel  Research & Development          1
# 147    44        No      travel_rarely                 Unknown          2
# 148    34        No  travel_frequently         Human Resources          3
# 149    39        No            Unknown                 Unknown          4
# 150    55        No      travel_rarely                 Unknown          2
# 151    51        No            Unknown                 Unknown          3
# 152    58       Yes            Unknown  Research & Development          4
# 153    48        No            Unknown  Research & Development          3
# 154    29        No      travel_rarely         Human Resources          3
# 155    34        No            Unknown                   Sales          3
# 156    42        No  travel_frequently  Research & Development          2
# 157    57        No      travel_rarely  Research & Development          2
# 158    34       Yes      travel_rarely                   Sales          4
# 159    54        No  travel_frequently                 Unknown          4
# 160    34        No      travel_rarely                   Sales          3
# 161    29        No            Unknown  Research & Development          1
# 162    35        No      travel_rarely  Research & Development          3
# 163    35       Yes            Unknown                   Sales          4
# 164    34        No      travel_rarely  Research & Development          3
# 165    43        No            Unknown                   Sales          3
# 166    58        No         non-travel                 Unknown          3
# 167    36        No      travel_rarely                   Sales          4
# 168    43        No      travel_rarely  Research & Development          3
# 169    55        No            Unknown                 Unknown          4
# 170    42        No            Unknown  Research & Development          2
# 171    40        No            Unknown  Research & Development          3
# 172    56       Yes            Unknown  Research & Development          2
# 173    39        No      travel_rarely                   Sales          1
# 174    53        No      travel_rarely                 Unknown          4
# 175    27        No  travel_frequently                   Sales          3
# 176    30        No  travel_frequently  Research & Development          2
# 177    35        No            Unknown                   Sales          5
# 178    32        No      travel_rarely  Research & Development          3
# 179    30        No      travel_rarely  Research & Development          1
# 180    46       Yes            Unknown                   Sales          2
# 181    30        No      travel_rarely                   Sales          2
# 182    32        No            Unknown                   Sales          4
# 183    35        No      travel_rarely                   Sales          5
# 184    32        No            Unknown                   Sales          3
# 185    41        No      travel_rarely  Research & Development          3
# 186    40        No      travel_rarely                 Unknown          1
# 187    45        No            Unknown                 Unknown          2
# 188    32       Yes      travel_rarely                   Sales          4
# 189    30        No         non-travel  Research & Development          1
# 190    37        No            Unknown  Research & Development          3
# 191    37        No            Unknown                   Sales          4
# 192    40        No            Unknown  Research & Development          2
# 193    36        No         non-travel  Research & Development          4
# 194    32        No      travel_rarely                   Sales          3
# 195    38        No            Unknown  Research & Development          2
# 196    30        No      travel_rarely  Research & Development          2
# 197    39        No            Unknown                 Unknown          1
# 198    60        No            Unknown                 Unknown          3
# 199    30        No            Unknown                   Sales          4
# 200    31        No      travel_rarely  Research & Development          1
# 201    33       Yes            Unknown  Research & Development          3
# 202    50        No            Unknown  Research & Development          1
# 203    32        No            Unknown  Research & Development          4
# 204    42        No            Unknown  Research & Development          3
# 205    49       Yes            Unknown                   Sales          3
# 206    27        No            Unknown  Research & Development          1
# 207    33        No      travel_rarely                   Sales          3
# 208    52        No            Unknown  Research & Development          4
# 209    32        No            Unknown                   Sales          2
# 210    36        No            Unknown  Research & Development          1
# 211    31        No         non-travel                   Sales          2
# 212    36        No      travel_rarely  Research & Development          4
# 213    52        No            Unknown                 Unknown          2
# 214    33        No         non-travel                 Unknown          3
# 215    45        No         non-travel  Research & Development          2
# 216    36        No      travel_rarely  Research & Development          5
# 217    49        No            Unknown                   Sales          4
# 218    29       Yes            Unknown                   Sales          1
# 219    29        No            Unknown  Research & Development          1
# 220    37        No            Unknown  Research & Development          3
# 221    33        No      travel_rarely                   Sales          5
# 222    34        No  travel_frequently  Research & Development          3
# 223    28        No         non-travel  Research & Development          3
# 224    31        No         non-travel                   Sales          4
# 225    42        No         non-travel                 Unknown          1
# 226    40        No      travel_rarely  Research & Development          3
# 227    34        No            Unknown                   Sales          2
# 228    58        No      travel_rarely  Research & Development          3
# 229    31       Yes  travel_frequently  Research & Development          5
# 230    40        No         non-travel  Research & Development          1
# 231    53        No            Unknown  Research & Development          3
# 232    34        No            Unknown  Research & Development          3
# 233    35        No      travel_rarely  Research & Development          3
# 234    37        No            Unknown  Research & Development          3
# 235    42        No  travel_frequently  Research & Development          3
# 236    45        No            Unknown  Research & Development          4
# 237    30       Yes      travel_rarely                   Sales          3
# 238    38        No      travel_rarely                   Sales          3
# 239    50        No            Unknown  Research & Development          5
# 240    39        No      travel_rarely  Research & Development          2
# 241    34        No      travel_rarely  Research & Development          3
# 242    54        No      travel_rarely  Research & Development          5
# 243    41        No      travel_rarely                   Sales          3
# 244    39        No            Unknown  Research & Development          3
# 245    40        No      travel_rarely                 Unknown          4
# 246    33        No            Unknown  Research & Development          3
# 247    36        No            Unknown  Research & Development          3
# 248    33        No            Unknown  Research & Development          4
# 249    34        No      travel_rarely                   Sales          2
# 250    29        No  travel_frequently  Research & Development          1
# 251    46        No      travel_rarely  Research & Development          2
# 252    27        No      travel_rarely                   Sales          1
# 253    31        No            Unknown  Research & Development          3
# 254    45        No      travel_rarely  Research & Development          2
# 255    34        No      travel_rarely                   Sales          3
# 256    31        No            Unknown  Research & Development          3
# 257    35        No            Unknown                   Sales          4
# 258    39        No      travel_rarely                   Sales          4
# 259    40        No      travel_rarely                   Sales          2
# 260    30        No      travel_rarely  Research & Development          2
# 261    47        No            Unknown  Research & Development          1
# 262    52        No         non-travel                   Sales          4
# 263    49        No  travel_frequently  Research & Development          1
# 264    33        No  travel_frequently  Research & Development          4
# 265    32        No            Unknown  Research & Development          2
# 266    38        No  travel_frequently  Research & Development          3
# 267    36        No      travel_rarely  Research & Development          3
# 268    42        No            Unknown                   Sales          4
# 269    31        No            Unknown  Research & Development          4
# 270    31        No      travel_rarely  Research & Development          4
# 271    51        No            Unknown                   Sales          4
# 272    34       Yes  travel_frequently  Research & Development          3
# 273    36        No            Unknown                   Sales          2
# 274    30        No  travel_frequently  Research & Development          3
# 275    33        No         non-travel                   Sales          2
# 276    31       Yes            Unknown                   Sales          4
# 277    41        No      travel_rarely                   Sales          1
# 278    26        No      travel_rarely         Human Resources          1
# 279    32        No            Unknown                   Sales          2
# 280    40        No  travel_frequently  Research & Development          3
# 281    53        No      travel_rarely                   Sales          2
# 282    29        No         non-travel  Research & Development          1
# 283    36        No  travel_frequently  Research & Development          2
# 284    33        No      travel_rarely  Research & Development          3
# 285    51        No      travel_rarely  Research & Development          3
# 286    27        No      travel_rarely  Research & Development          3
# 287    37        No            Unknown  Research & Development          3
# 288    38        No            Unknown  Research & Development          3
# 289    49        No         non-travel  Research & Development          4
# 290    27        No            Unknown                   Sales          3
# 291    45        No            Unknown                   Sales          3
# 292    35        No            Unknown                   Sales          3
# 293    33       Yes      travel_rarely  Research & Development          2
# 294    52        No            Unknown                 Unknown          4
# 295    40        No            Unknown  Research & Development          2
# 296    38        No         non-travel                   Sales          2
# 297    46        No            Unknown                 Unknown          3
# 298    45        No      travel_rarely  Research & Development          2
# 307    32        No            Unknown  Research & Development          4
# 312    29        No      travel_rarely                   Sales          1
# 313    37        No            Unknown  Research & Development          3
# 318    37        No            Unknown  Research & Development          3
# 319    56        No            Unknown                   Sales          3
# 321    46        No            Unknown  Research & Development          3
# 322    30        No         non-travel  Research & Development          3
# 325    45        No      travel_rarely                   Sales          3
# 332    37        No      travel_rarely  Research & Development          3
# 333    54        No            Unknown         Human Resources          4
# 334    38        No      travel_rarely                   Sales          4
# 341    32        No      travel_rarely  Research & Development          2
# 345    28       Yes            Unknown  Research & Development          2
# 353    40        No            Unknown  Research & Development          2
# 356    29        No      travel_rarely  Research & Development          2
# 358    28        No            Unknown                   Sales          4
# 359    26       Yes            Unknown  Research & Development          2
# 364    31        No            Unknown  Research & Development          3
# 368    39        No      travel_rarely                   Sales          5
# 370    46        No            Unknown  Research & Development          2
# 371    54        No      travel_rarely  Research & Development          3
# 372    30        No      travel_rarely  Research & Development          2
# 373    26        No            Unknown  Research & Development          2
# 374    55        No  travel_frequently  Research & Development          4
# 375    50        No         non-travel                   Sales          3
# 376    32        No         non-travel  Research & Development          4
# 377    53        No  travel_frequently                   Sales          3
# 378    40        No      travel_rarely                   Sales          3
# 379    55        No            Unknown                 Unknown          1
# 380    28       Yes         non-travel  Research & Development          2
# 381    28        No      travel_rarely  Research & Development          3
# 382    35       Yes            Unknown                   Sales          3
# 383    33       Yes  travel_frequently  Research & Development          4
# 384    25       Yes            Unknown  Research & Development          1
# 385    38        No            Unknown                   Sales          4
# 386    28        No            Unknown  Research & Development          3
# 387    43        No  travel_frequently  Research & Development          3
# 388    39       Yes  travel_frequently  Research & Development          3
# 389    40        No      travel_rarely  Research & Development          3
# 390    29        No      travel_rarely  Research & Development          1
# 391    40        No            Unknown  Research & Development          4
# 392    26        No      travel_rarely  Research & Development          4
# 393    35        No      travel_rarely  Research & Development          3
# 394    53        No            Unknown  Research & Development          2
# 395    35        No            Unknown                   Sales          4
# 396    33        No            Unknown                   Sales          3
# 397    36        No            Unknown  Research & Development          4
# 398    30        No      travel_rarely  Research & Development          4
# 399    60        No            Unknown                   Sales          4
# 400    32        No            Unknown  Research & Development          2
# 401    36        No            Unknown  Research & Development          3
# 402    27        No      travel_rarely  Research & Development          3
# 403    43        No            Unknown  Research & Development          3
# 404    29        No      travel_rarely  Research & Development          3
# 405    59        No            Unknown  Research & Development          4
# 406    43        No      travel_rarely                   Sales          4
# 407    44       Yes      travel_rarely  Research & Development          3
# 408    29       Yes            Unknown  Research & Development          3
# 409    32        No      travel_rarely                   Sales          3
# 410    36        No      travel_rarely  Research & Development          4
# 411    52       Yes            Unknown                   Sales          3
# 412    39        No      travel_rarely  Research & Development          2
# 413    34        No            Unknown  Research & Development          3
# 414    38        No            Unknown                   Sales          2
# 415    36        No  travel_frequently                   Sales          3
# 416    35        No            Unknown  Research & Development          3
# 417    55       Yes            Unknown                   Sales          4
# 418    34        No            Unknown  Research & Development          3
# 419    43        No            Unknown  Research & Development          3
# 420    42        No      travel_rarely                 Unknown          3
# 421    26        No      travel_rarely  Research & Development          3
# 422    29       Yes            Unknown  Research & Development          1
# 423    54        No            Unknown  Research & Development          3
# 424    55        No            Unknown  Research & Development          4
# 425    40        No         non-travel  Research & Development          4
# 426    31        No            Unknown                   Sales          2
# 427    46       Yes            Unknown                   Sales          3
# 428    45        No      travel_rarely  Research & Development          3
# 429    49        No      travel_rarely  Research & Development          4
# 430    29        No      travel_rarely                   Sales          3
# 431    29       Yes            Unknown  Research & Development          4
# 432    29        No            Unknown  Research & Development          1
# 433    40        No      travel_rarely         Human Resources          2
# 434    48        No            Unknown                   Sales          4
# 435    53       Yes            Unknown  Research & Development          5
# 436    44        No            Unknown  Research & Development          3
# 437    45        No            Unknown  Research & Development          5
# 438    45        No         non-travel                   Sales          3
# 439    34        No  travel_frequently  Research & Development          4
# 440    39        No            Unknown  Research & Development          5
# 441    27        No            Unknown  Research & Development          3
# 442    45        No      travel_rarely  Research & Development          2
# 443    44        No            Unknown         Human Resources          5
# 444    25        No            Unknown  Research & Development          1
# 445    49        No            Unknown                 Unknown          3
# 446    48       Yes  travel_frequently                   Sales          2
# 447    26        No            Unknown  Research & Development          3
# 448    44        No      travel_rarely  Research & Development          3
# 449    36        No            Unknown                   Sales          4
# 450    46        No            Unknown  Research & Development          4
# 451    35        No            Unknown  Research & Development          4
# 452    30        No  travel_frequently  Research & Development          4
# 453    30        No            Unknown                   Sales          2
# 454    33        No         non-travel                   Sales          3
# 455    32        No            Unknown  Research & Development          4
# 457    31        No      travel_rarely                   Sales          4
# 462    45        No         non-travel                   Sales          4
# 465    40        No      travel_rarely  Research & Development          4
# 468    26        No  travel_frequently  Research & Development          3
# 470    47        No            Unknown  Research & Development          4
# 471    34        No      travel_rarely                   Sales          4
# 472    26        No            Unknown  Research & Development          3
# 473    27        No      travel_rarely                   Sales          3
# 474    31       Yes  travel_frequently                   Sales          4
# 475    33        No  travel_frequently  Research & Development          2
# 476    31        No            Unknown  Research & Development          3
# 477    35        No            Unknown  Research & Development          4
# 478    33        No      travel_rarely  Research & Development          2
# 479    39        No      travel_rarely  Research & Development          1
# 480    36        No      travel_rarely                   Sales          3
# 481    41        No      travel_rarely  Research & Development          4
# 482    34        No            Unknown                   Sales          3
# 483    38        No      travel_rarely                   Sales          2
# 484    39        No      travel_rarely  Research & Development          1
# 485    34        No      travel_rarely  Research & Development          4
# 486    44        No      travel_rarely  Research & Development          4
# 487    46        No            Unknown                   Sales          4
# 488    41        No  travel_frequently  Research & Development          3
# 489    39        No            Unknown  Research & Development          4
# 490    42        No      travel_rarely  Research & Development          3
# 491    33        No  travel_frequently  Research & Development          4
# 492    35        No      travel_rarely  Research & Development          4
# 493    33       Yes      travel_rarely                 Unknown          1
# 494    40        No      travel_rarely  Research & Development          3
# 495    41        No      travel_rarely                 Unknown          4
# 496    27        No            Unknown  Research & Development          3
# 497    52        No      travel_rarely                 Unknown          4
# 498    51        No      travel_rarely                 Unknown          4
# 499    47        No      travel_rarely                   Sales          2
# 500    50        No         non-travel  Research & Development          4
# 501    35        No      travel_rarely  Research & Development          1
# 502    39        No      travel_rarely  Research & Development          1
# 503    39        No  travel_frequently  Research & Development          3
# 504    41        No            Unknown  Research & Development          2
# 505    44       Yes            Unknown         Human Resources          2
# 506    42        No            Unknown                 Unknown          2
# 507    52        No      travel_rarely  Research & Development          4
# 508    38        No            Unknown         Human Resources          3
# 509    46        No            Unknown         Human Resources          2
# 510    35        No            Unknown  Research & Development          4
# 511    28        No      travel_rarely  Research & Development          1
# 512    44        No            Unknown  Research & Development          3
# 513    50        No            Unknown  Research & Development          5
# 514    55        No      travel_rarely                 Unknown          5
# 515    39        No            Unknown                   Sales          3
# 516    49        No            Unknown  Research & Development          4
# 517    45        No            Unknown  Research & Development          2
# 518    46        No            Unknown                   Sales          3
# 519    27        No            Unknown  Research & Development          3
# 520    42        No      travel_rarely                 Unknown          3
# 521    49        No            Unknown                   Sales          3
# 522    29        No      travel_rarely  Research & Development          2
# 523    34        No         non-travel                   Sales          4
# 524    37        No            Unknown  Research & Development          4
# 525    36        No            Unknown  Research & Development          3
# 526    45        No            Unknown  Research & Development          3
# 527    29        No      travel_rarely  Research & Development          3
# 528    26        No            Unknown  Research & Development          3
# 529    28        No            Unknown                   Sales          4
# 530    42        No  travel_frequently  Research & Development          4
# 531    31        No      travel_rarely                   Sales          1
# 532    37        No      travel_rarely  Research & Development          3
# 533    37        No         non-travel                   Sales          4
# 534    37        No      travel_rarely  Research & Development          4
# 535    24        No      travel_rarely  Research & Development          3
# 536    50        No            Unknown                 Unknown          3
# 537    34        No            Unknown  Research & Development          2
# 538    27        No  travel_frequently                   Sales          1
# 539    25        No            Unknown                   Sales          1
# 540    34        No            Unknown                   Sales          3
# 541    34        No            Unknown  Research & Development          4
# 542    35        No            Unknown  Research & Development          3
# 543    35        No            Unknown  Research & Development          1
# 544    33        No            Unknown  Research & Development          4
# 545    29        No            Unknown  Research & Development          4
# 546    29        No  travel_frequently  Research & Development          3
# 547    34        No            Unknown                   Sales          1
# 548    28        No      travel_rarely  Research & Development          4
# 549    44        No            Unknown  Research & Development          1
# 550    31        No      travel_rarely  Research & Development          2
# 551    26        No            Unknown  Research & Development          2
# 552    47        No      travel_rarely  Research & Development          3
# 553    37        No            Unknown  Research & Development          2
# 554    32        No            Unknown  Research & Development          4
# 555    32        No            Unknown  Research & Development          3
# 556    33        No         non-travel                   Sales          3
# 557    47       Yes            Unknown                   Sales          3
# 558    41       Yes            Unknown                   Sales          2
# 559    35        No      travel_rarely  Research & Development          3
# 560    29        No      travel_rarely  Research & Development          3
# 561    32        No      travel_rarely  Research & Development          3
# 562    35        No      travel_rarely  Research & Development          3
# 563    56        No            Unknown  Research & Development          3
# 564    28        No            Unknown                   Sales          3
# 565    25       Yes      travel_rarely                   Sales          3
# 566    56       Yes            Unknown  Research & Development          4
# 567    26        No            Unknown  Research & Development          3
# 568    32       Yes            Unknown  Research & Development          3
# 569    30        No      travel_rarely  Research & Development          3
# 570    50        No      travel_rarely                 Unknown          3
# 571    32        No            Unknown  Research & Development          5
# 572    45        No      travel_rarely                   Sales          2
# 573    43        No            Unknown  Research & Development          3
# 574    29       Yes            Unknown                   Sales          3
# 575    31        No         non-travel  Research & Development          4
# 576    33       Yes            Unknown  Research & Development          3
# 577    31       Yes            Unknown  Research & Development          2
# 578    37        No            Unknown                   Sales          4
# 579    50        No            Unknown  Research & Development          1
# 580    42        No  travel_frequently                   Sales          3
# 581    27        No            Unknown                   Sales          3
# 582    27        No         non-travel                   Sales          1
# 583    41        No      travel_rarely  Research & Development          3
# 584    37        No      travel_rarely  Research & Development          3
# 585    40       Yes            Unknown                   Sales          2
# 586    55        No            Unknown                 Unknown          3
# 587    26       Yes  travel_frequently  Research & Development          1
# 588    40        No      travel_rarely                   Sales          2
# 589    25        No            Unknown                   Sales          2
# 590    30        No            Unknown                   Sales          3
# 591    52        No      travel_rarely  Research & Development          3
# 592    42        No  travel_frequently  Research & Development          2
# 593    30        No      travel_rarely  Research & Development          3
# 594    35        No      travel_rarely  Research & Development          3
# 595    31        No      travel_rarely                 Unknown          3
# 596    35        No      travel_rarely                   Sales          3
# 597    25        No            Unknown                   Sales          1
# 598    32        No      travel_rarely  Research & Development          4
# 599    47       Yes            Unknown                   Sales          2
# 600    30        No  travel_frequently  Research & Development          4
# 601    45        No            Unknown                   Sales          3
# 602    36        No      travel_rarely         Human Resources          3
# 603    31        No            Unknown  Research & Development          4
# 604    37        No  travel_frequently                   Sales          2
# 605    39        No      travel_rarely         Human Resources          3
# 606    42        No            Unknown                   Sales          2
# 607    30        No      travel_rarely                   Sales          2
# 608    50        No            Unknown  Research & Development          2
# 609    59        No      travel_rarely                   Sales          2
# 610    54        No            Unknown                   Sales          4
# 611    56        No            Unknown  Research & Development          3
# 612    48        No            Unknown                 Unknown          4
# 613    39        No            Unknown  Research & Development          3
# 614    35        No      travel_rarely         Human Resources          4
# 615    42        No      travel_rarely                   Sales          4
# 616    44       Yes            Unknown  Research & Development          4
# 617    29        No      travel_rarely  Research & Development          1
# 618    33        No            Unknown         Human Resources          3
# 619    54        No  travel_frequently  Research & Development          4
# 620    46        No            Unknown                   Sales          2
# 621    30        No         non-travel  Research & Development          2
# 622    32       Yes      travel_rarely  Research & Development          2
# 623    40       Yes            Unknown                   Sales          4
# 624    34        No         non-travel  Research & Development          1
# 625    39        No      travel_rarely                   Sales          4
# 626    37        No            Unknown  Research & Development          1
# 627    33        No            Unknown                   Sales          1
# 628    39        No         non-travel  Research & Development          2
# 629    52        No      travel_rarely  Research & Development          4
# 630    36        No            Unknown                   Sales          4
# 631    36        No            Unknown  Research & Development          4
# 632    24        No      travel_rarely                   Sales          1
# 633    34        No      travel_rarely  Research & Development          3
# 634    28        No            Unknown                   Sales          3
# 635    33        No      travel_rarely  Research & Development          4
# 636    47        No      travel_rarely                   Sales          3
# 637    40       Yes            Unknown  Research & Development          4
# 638    45        No      travel_rarely  Research & Development          3
# 639    40        No      travel_rarely                   Sales          2
# 640    29        No            Unknown  Research & Development          1
# 641    40        No            Unknown                   Sales          2
# 642    43        No            Unknown  Research & Development          3
# 643    30        No            Unknown  Research & Development          3
# 644    38        No            Unknown  Research & Development          2
# 645    37        No      travel_rarely  Research & Development          3
# 646    39        No      travel_rarely  Research & Development          3
# 647    36        No      travel_rarely  Research & Development          2
# 648    23       Yes      travel_rarely  Research & Development          1
# 649    35        No            Unknown  Research & Development          4
# 650    31        No  travel_frequently  Research & Development          1
# 651    38        No      travel_rarely  Research & Development          2
# 652    35        No            Unknown  Research & Development          4
# 653    40        No            Unknown  Research & Development          3
# 654    27        No  travel_frequently  Research & Development          2
# 655    41        No            Unknown                   Sales          3
# 656    33        No      travel_rarely                   Sales          4
# 657    49        No            Unknown  Research & Development          1
# 658    36        No         non-travel  Research & Development          4
# 659    41        No            Unknown                   Sales          3
# 660    29        No            Unknown  Research & Development          4
# 661    31        No         non-travel  Research & Development          3
# 662    36       Yes      travel_rarely                   Sales          4
# 663    43        No      travel_rarely  Research & Development          2
# 664    33        No  travel_frequently                   Sales          3
# 665    44        No            Unknown                   Sales          5
# 666    38        No            Unknown  Research & Development          5
# 667    50        No            Unknown  Research & Development          2
# 668    59        No  travel_frequently                   Sales          1
# 669    40        No  travel_frequently  Research & Development          4
# 670    54        No      travel_rarely  Research & Development          4
# 671    50        No            Unknown  Research & Development          3
# 672    54        No         non-travel                 Unknown          3
# 673    24        No            Unknown  Research & Development          1
